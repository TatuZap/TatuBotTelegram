# %%
from random import choice

list_inic  = ('minhas', 'quero minhas', 'quais as minhas', 'qual minha', 'diga a ','informe a','quero saber as', 'me fale as','qual é', 'diz a','','','')
list_fim   = ('materias', 'materia', 'sala', 'disciplina','professor','local','turma','turmas','professores','disciplinas','salas','aula','aulas','grade','horario','classe','classes')
list_tempo = ('','','','agora','que devo ir','na segunda','na terca','na quarta','na quinta','na sexta','de manha','de tarde','de noite')

# %%
my_dict = {};
dict2 = {"pattern":[]};
for i in range(200):
  a = choice(list_inic)+' '+choice(list_fim)+' '+choice(list_tempo)
  my_dict[a]=('my_classes')
  dict2['pattern'].append(a)
my_dict
# Out:
# {'qual é professores na quinta': 'my_classes',
#  ' local na quarta': 'my_classes',
#  ' sala de manha': 'my_classes',
#  ' professores na terca': 'my_classes',
#  'quero saber as local de manha': 'my_classes',
#  'informe a aula na segunda': 'my_classes',
#  'qual minha turma de tarde': 'my_classes',
#  'minhas local de tarde': 'my_classes',
#  ' classes de manha': 'my_classes',
#  'minhas grade que devo ir': 'my_classes',
#  ' horario de manha': 'my_classes',
#  'diga a  classes na sexta': 'my_classes',
#  'diz a grade ': 'my_classes',
#  'informe a salas que devo ir': 'my_classes',
#  'minhas disciplinas na segunda': 'my_classes',
#  ' classe na sexta': 'my_classes',
#  'quero saber as sala na segunda': 'my_classes',
#  ' local ': 'my_classes',
#  ' disciplina de manha': 'my_classes',
#  'minhas professores agora': 'my_classes',
#  'diga a  sala na quinta': 'my_classes',
#  'qual minha materia de manha': 'my_classes',
#  'qual é professor ': 'my_classes',
#  'quero minhas aulas de manha': 'my_classes',
#  ' disciplinas na quinta': 'my_classes',
#  'quero saber as sala agora': 'my_classes',
#  ' aulas de noite': 'my_classes',
#  ' salas agora': 'my_classes',
#  ' classes agora': 'my_classes',
#  'diz a disciplina na quarta': 'my_classes',
#  'informe a local que devo ir': 'my_classes',
#  'qual minha horario na sexta': 'my_classes',
#  'quero saber as aula na quinta': 'my_classes',
#  'quais as minhas classes ': 'my_classes',
#  'quais as minhas horario de noite': 'my_classes',
#  'qual é aula de tarde': 'my_classes',
#  'minhas grade na sexta': 'my_classes',
#  'quero saber as materia de noite': 'my_classes',
#  'quais as minhas disciplina de manha': 'my_classes',
#  'quais as minhas materia de manha': 'my_classes',
#  'diz a salas na segunda': 'my_classes',
#  'diz a local ': 'my_classes',
#  'me fale as salas ': 'my_classes',
#  ' local de tarde': 'my_classes',
#  ' materia ': 'my_classes',
#  'qual minha sala de manha': 'my_classes',
#  'quero minhas materia na terca': 'my_classes',
#  'quero saber as sala que devo ir': 'my_classes',
#  'quero minhas materias na quinta': 'my_classes',
#  'qual é grade ': 'my_classes',
#  'quero minhas salas na quinta': 'my_classes',
#  'quais as minhas aulas de manha': 'my_classes',
#  'informe a sala ': 'my_classes',
#  'diz a aula que devo ir': 'my_classes',
#  'informe a classe na quinta': 'my_classes',
#  'diz a materia de noite': 'my_classes',
#  'diz a professores de noite': 'my_classes',
#  'qual minha aulas de manha': 'my_classes',
#  'diz a materia de tarde': 'my_classes',
#  'me fale as materia na quinta': 'my_classes',
#  'minhas aulas de tarde': 'my_classes',
#  'quais as minhas local na terca': 'my_classes',
#  'diz a turma na segunda': 'my_classes',
#  'diga a  disciplina de noite': 'my_classes',
#  'qual é horario ': 'my_classes',
#  'me fale as aula ': 'my_classes',
#  'informe a disciplina na quinta': 'my_classes',
#  'quais as minhas sala na quarta': 'my_classes',
#  'quero saber as grade na quinta': 'my_classes',
#  'diga a  professores na quarta': 'my_classes',
#  'quero minhas horario na terca': 'my_classes',
#  'quero minhas turmas na quarta': 'my_classes',
#  'minhas classe de manha': 'my_classes',
#  'diz a turma de tarde': 'my_classes',
#  'qual é materias que devo ir': 'my_classes',
#  'quero saber as local na quarta': 'my_classes',
#  ' professores na segunda': 'my_classes',
#  'quero minhas horario de manha': 'my_classes',
#  'quais as minhas classes na quinta': 'my_classes',
#  'me fale as disciplina de noite': 'my_classes',
#  'qual é disciplina ': 'my_classes',
#  'minhas disciplina na segunda': 'my_classes',
#  'qual é sala ': 'my_classes',
#  'qual é local na terca': 'my_classes',
#  'quero saber as horario ': 'my_classes',
#  ' sala ': 'my_classes',
#  'diga a  disciplinas ': 'my_classes',
#  'me fale as horario de tarde': 'my_classes',
#  'informe a turma na sexta': 'my_classes',
#  'diz a aulas de noite': 'my_classes',
#  'qual é local na quarta': 'my_classes',
#  ' turma de noite': 'my_classes',
#  'diga a  aula de tarde': 'my_classes',
#  ' sala na segunda': 'my_classes',
#  ' professores na quinta': 'my_classes',
#  'me fale as turmas que devo ir': 'my_classes',
#  'diz a aula ': 'my_classes',
#  ' classe de tarde': 'my_classes',
#  'qual é classes de tarde': 'my_classes',
#  'quero minhas salas na terca': 'my_classes',
#  ' turma agora': 'my_classes',
#  'qual minha disciplinas ': 'my_classes',
#  'diga a  professor de manha': 'my_classes',
#  'qual é turma na terca': 'my_classes',
#  ' classes que devo ir': 'my_classes',
#  'diga a  turma ': 'my_classes',
#  ' materias ': 'my_classes',
#  ' aula agora': 'my_classes',
#  'quero minhas materia de tarde': 'my_classes',
#  'minhas sala na sexta': 'my_classes',
#  'qual é disciplina agora': 'my_classes',
#  'informe a disciplina de tarde': 'my_classes',
#  ' aulas que devo ir': 'my_classes',
#  ' classe que devo ir': 'my_classes',
#  'informe a grade que devo ir': 'my_classes',
#  'qual minha sala que devo ir': 'my_classes',
#  'quero minhas disciplina agora': 'my_classes',
#  'quais as minhas disciplinas ': 'my_classes',
#  'me fale as disciplina na terca': 'my_classes',
#  'minhas professores ': 'my_classes',
#  'minhas classe na terca': 'my_classes',
#  ' disciplina na sexta': 'my_classes',
#  'quero minhas professor na segunda': 'my_classes',
#  'diz a turma na quarta': 'my_classes',
#  ' salas de noite': 'my_classes',
#  'minhas aula ': 'my_classes',
#  'quero minhas sala de manha': 'my_classes',
#  'diz a professor na terca': 'my_classes',
#  ' professores ': 'my_classes',
#  'diz a aulas na segunda': 'my_classes',
#  'minhas turma ': 'my_classes',
#  'minhas classe na segunda': 'my_classes',
#  'informe a salas na terca': 'my_classes',
#  'informe a grade de noite': 'my_classes',
#  'informe a salas de noite': 'my_classes',
#  'minhas disciplina na sexta': 'my_classes',
#  ' sala de tarde': 'my_classes',
#  'diga a  professores de tarde': 'my_classes',
#  'quero saber as professor na terca': 'my_classes',
#  'quero minhas disciplinas na quinta': 'my_classes',
#  'informe a classe na quarta': 'my_classes',
#  'diz a turma agora': 'my_classes',
#  'qual é turma de tarde': 'my_classes',
#  'quero saber as disciplina na quinta': 'my_classes',
#  ' disciplina que devo ir': 'my_classes',
#  ' turmas na quarta': 'my_classes',
#  ' salas que devo ir': 'my_classes',
#  'diz a disciplinas na sexta': 'my_classes',
#  'me fale as sala de tarde': 'my_classes',
#  ' salas na sexta': 'my_classes',
#  'qual é professor na segunda': 'my_classes',
#  'quero minhas classe na segunda': 'my_classes',
#  ' aulas ': 'my_classes',
#  'diz a disciplinas de tarde': 'my_classes',
#  'quero saber as local ': 'my_classes',
#  'qual é professor agora': 'my_classes',
#  'minhas aula de manha': 'my_classes',
#  ' grade que devo ir': 'my_classes',
#  ' disciplina na segunda': 'my_classes',
#  'minhas disciplinas que devo ir': 'my_classes',
#  'quais as minhas sala agora': 'my_classes',
#  'diga a  turma agora': 'my_classes',
#  'informe a salas ': 'my_classes',
#  ' classes de tarde': 'my_classes',
#  'diz a professor ': 'my_classes',
#  'quais as minhas turma na sexta': 'my_classes',
#  ' local de manha': 'my_classes',
#  'diz a horario ': 'my_classes',
#  'quero minhas turma na quarta': 'my_classes',
#  'quais as minhas grade de manha': 'my_classes',
#  ' materias na sexta': 'my_classes',
#  'qual minha professor na terca': 'my_classes',
#  'quero saber as turma na quarta': 'my_classes',
#  'diz a aulas de tarde': 'my_classes',
#  'me fale as disciplinas agora': 'my_classes',
#  'diz a aulas ': 'my_classes',
#  'minhas turma na sexta': 'my_classes',
#  'me fale as grade ': 'my_classes',
#  'quero minhas classe de tarde': 'my_classes',
#  'minhas grade na quarta': 'my_classes',
#  ' turmas na segunda': 'my_classes',
#  'minhas salas de tarde': 'my_classes',
#  'quais as minhas local de manha': 'my_classes',
#  'qual é disciplinas agora': 'my_classes',
#  'minhas classes agora': 'my_classes',
#  'informe a disciplinas ': 'my_classes',
#  'qual é classe na segunda': 'my_classes'}

# %%
list_inic_f = ('','','','quero saber','informe','qual','que hora','quando','quando sai','quero que sai','vai sair')
list_fim_f = ('fretado','fretados','onibus','busao','lotação')

# %%
for i in range(50):
  a = choice(list_inic_f)+' '+choice(list_fim_f)
  my_dict[a] = 'bus_info'
  dict2['pattern'].append(a)
my_dict
# Out:
# {'qual é professores na quinta': 'my_classes',
#  ' local na quarta': 'my_classes',
#  ' sala de manha': 'my_classes',
#  ' professores na terca': 'my_classes',
#  'quero saber as local de manha': 'my_classes',
#  'informe a aula na segunda': 'my_classes',
#  'qual minha turma de tarde': 'my_classes',
#  'minhas local de tarde': 'my_classes',
#  ' classes de manha': 'my_classes',
#  'minhas grade que devo ir': 'my_classes',
#  ' horario de manha': 'my_classes',
#  'diga a  classes na sexta': 'my_classes',
#  'diz a grade ': 'my_classes',
#  'informe a salas que devo ir': 'my_classes',
#  'minhas disciplinas na segunda': 'my_classes',
#  ' classe na sexta': 'my_classes',
#  'quero saber as sala na segunda': 'my_classes',
#  ' local ': 'my_classes',
#  ' disciplina de manha': 'my_classes',
#  'minhas professores agora': 'my_classes',
#  'diga a  sala na quinta': 'my_classes',
#  'qual minha materia de manha': 'my_classes',
#  'qual é professor ': 'my_classes',
#  'quero minhas aulas de manha': 'my_classes',
#  ' disciplinas na quinta': 'my_classes',
#  'quero saber as sala agora': 'my_classes',
#  ' aulas de noite': 'my_classes',
#  ' salas agora': 'my_classes',
#  ' classes agora': 'my_classes',
#  'diz a disciplina na quarta': 'my_classes',
#  'informe a local que devo ir': 'my_classes',
#  'qual minha horario na sexta': 'my_classes',
#  'quero saber as aula na quinta': 'my_classes',
#  'quais as minhas classes ': 'my_classes',
#  'quais as minhas horario de noite': 'my_classes',
#  'qual é aula de tarde': 'my_classes',
#  'minhas grade na sexta': 'my_classes',
#  'quero saber as materia de noite': 'my_classes',
#  'quais as minhas disciplina de manha': 'my_classes',
#  'quais as minhas materia de manha': 'my_classes',
#  'diz a salas na segunda': 'my_classes',
#  'diz a local ': 'my_classes',
#  'me fale as salas ': 'my_classes',
#  ' local de tarde': 'my_classes',
#  ' materia ': 'my_classes',
#  'qual minha sala de manha': 'my_classes',
#  'quero minhas materia na terca': 'my_classes',
#  'quero saber as sala que devo ir': 'my_classes',
#  'quero minhas materias na quinta': 'my_classes',
#  'qual é grade ': 'my_classes',
#  'quero minhas salas na quinta': 'my_classes',
#  'quais as minhas aulas de manha': 'my_classes',
#  'informe a sala ': 'my_classes',
#  'diz a aula que devo ir': 'my_classes',
#  'informe a classe na quinta': 'my_classes',
#  'diz a materia de noite': 'my_classes',
#  'diz a professores de noite': 'my_classes',
#  'qual minha aulas de manha': 'my_classes',
#  'diz a materia de tarde': 'my_classes',
#  'me fale as materia na quinta': 'my_classes',
#  'minhas aulas de tarde': 'my_classes',
#  'quais as minhas local na terca': 'my_classes',
#  'diz a turma na segunda': 'my_classes',
#  'diga a  disciplina de noite': 'my_classes',
#  'qual é horario ': 'my_classes',
#  'me fale as aula ': 'my_classes',
#  'informe a disciplina na quinta': 'my_classes',
#  'quais as minhas sala na quarta': 'my_classes',
#  'quero saber as grade na quinta': 'my_classes',
#  'diga a  professores na quarta': 'my_classes',
#  'quero minhas horario na terca': 'my_classes',
#  'quero minhas turmas na quarta': 'my_classes',
#  'minhas classe de manha': 'my_classes',
#  'diz a turma de tarde': 'my_classes',
#  'qual é materias que devo ir': 'my_classes',
#  'quero saber as local na quarta': 'my_classes',
#  ' professores na segunda': 'my_classes',
#  'quero minhas horario de manha': 'my_classes',
#  'quais as minhas classes na quinta': 'my_classes',
#  'me fale as disciplina de noite': 'my_classes',
#  'qual é disciplina ': 'my_classes',
#  'minhas disciplina na segunda': 'my_classes',
#  'qual é sala ': 'my_classes',
#  'qual é local na terca': 'my_classes',
#  'quero saber as horario ': 'my_classes',
#  ' sala ': 'my_classes',
#  'diga a  disciplinas ': 'my_classes',
#  'me fale as horario de tarde': 'my_classes',
#  'informe a turma na sexta': 'my_classes',
#  'diz a aulas de noite': 'my_classes',
#  'qual é local na quarta': 'my_classes',
#  ' turma de noite': 'my_classes',
#  'diga a  aula de tarde': 'my_classes',
#  ' sala na segunda': 'my_classes',
#  ' professores na quinta': 'my_classes',
#  'me fale as turmas que devo ir': 'my_classes',
#  'diz a aula ': 'my_classes',
#  ' classe de tarde': 'my_classes',
#  'qual é classes de tarde': 'my_classes',
#  'quero minhas salas na terca': 'my_classes',
#  ' turma agora': 'my_classes',
#  'qual minha disciplinas ': 'my_classes',
#  'diga a  professor de manha': 'my_classes',
#  'qual é turma na terca': 'my_classes',
#  ' classes que devo ir': 'my_classes',
#  'diga a  turma ': 'my_classes',
#  ' materias ': 'my_classes',
#  ' aula agora': 'my_classes',
#  'quero minhas materia de tarde': 'my_classes',
#  'minhas sala na sexta': 'my_classes',
#  'qual é disciplina agora': 'my_classes',
#  'informe a disciplina de tarde': 'my_classes',
#  ' aulas que devo ir': 'my_classes',
#  ' classe que devo ir': 'my_classes',
#  'informe a grade que devo ir': 'my_classes',
#  'qual minha sala que devo ir': 'my_classes',
#  'quero minhas disciplina agora': 'my_classes',
#  'quais as minhas disciplinas ': 'my_classes',
#  'me fale as disciplina na terca': 'my_classes',
#  'minhas professores ': 'my_classes',
#  'minhas classe na terca': 'my_classes',
#  ' disciplina na sexta': 'my_classes',
#  'quero minhas professor na segunda': 'my_classes',
#  'diz a turma na quarta': 'my_classes',
#  ' salas de noite': 'my_classes',
#  'minhas aula ': 'my_classes',
#  'quero minhas sala de manha': 'my_classes',
#  'diz a professor na terca': 'my_classes',
#  ' professores ': 'my_classes',
#  'diz a aulas na segunda': 'my_classes',
#  'minhas turma ': 'my_classes',
#  'minhas classe na segunda': 'my_classes',
#  'informe a salas na terca': 'my_classes',
#  'informe a grade de noite': 'my_classes',
#  'informe a salas de noite': 'my_classes',
#  'minhas disciplina na sexta': 'my_classes',
#  ' sala de tarde': 'my_classes',
#  'diga a  professores de tarde': 'my_classes',
#  'quero saber as professor na terca': 'my_classes',
#  'quero minhas disciplinas na quinta': 'my_classes',
#  'informe a classe na quarta': 'my_classes',
#  'diz a turma agora': 'my_classes',
#  'qual é turma de tarde': 'my_classes',
#  'quero saber as disciplina na quinta': 'my_classes',
#  ' disciplina que devo ir': 'my_classes',
#  ' turmas na quarta': 'my_classes',
#  ' salas que devo ir': 'my_classes',
#  'diz a disciplinas na sexta': 'my_classes',
#  'me fale as sala de tarde': 'my_classes',
#  ' salas na sexta': 'my_classes',
#  'qual é professor na segunda': 'my_classes',
#  'quero minhas classe na segunda': 'my_classes',
#  ' aulas ': 'my_classes',
#  'diz a disciplinas de tarde': 'my_classes',
#  'quero saber as local ': 'my_classes',
#  'qual é professor agora': 'my_classes',
#  'minhas aula de manha': 'my_classes',
#  ' grade que devo ir': 'my_classes',
#  ' disciplina na segunda': 'my_classes',
#  'minhas disciplinas que devo ir': 'my_classes',
#  'quais as minhas sala agora': 'my_classes',
#  'diga a  turma agora': 'my_classes',
#  'informe a salas ': 'my_classes',
#  ' classes de tarde': 'my_classes',
#  'diz a professor ': 'my_classes',
#  'quais as minhas turma na sexta': 'my_classes',
#  ' local de manha': 'my_classes',
#  'diz a horario ': 'my_classes',
#  'quero minhas turma na quarta': 'my_classes',
#  'quais as minhas grade de manha': 'my_classes',
#  ' materias na sexta': 'my_classes',
#  'qual minha professor na terca': 'my_classes',
#  'quero saber as turma na quarta': 'my_classes',
#  'diz a aulas de tarde': 'my_classes',
#  'me fale as disciplinas agora': 'my_classes',
#  'diz a aulas ': 'my_classes',
#  'minhas turma na sexta': 'my_classes',
#  'me fale as grade ': 'my_classes',
#  'quero minhas classe de tarde': 'my_classes',
#  'minhas grade na quarta': 'my_classes',
#  ' turmas na segunda': 'my_classes',
#  'minhas salas de tarde': 'my_classes',
#  'quais as minhas local de manha': 'my_classes',
#  'qual é disciplinas agora': 'my_classes',
#  'minhas classes agora': 'my_classes',
#  'informe a disciplinas ': 'my_classes',
#  'qual é classe na segunda': 'my_classes',
#  ' fretado': 'bus_info',
#  'informe busao': 'bus_info',
#  'quero que sai fretados': 'bus_info',
#  'quero que sai lotação': 'bus_info',
#  'que hora busao': 'bus_info',
#  'quando fretado': 'bus_info',
#  'informe fretados': 'bus_info',
#  ' onibus': 'bus_info',
#  'vai sair fretados': 'bus_info',
#  'quero saber busao': 'bus_info',
#  ' lotação': 'bus_info',
#  'quando sai onibus': 'bus_info',
#  'quando sai lotação': 'bus_info',
#  'qual lotação': 'bus_info',
#  'quando sai busao': 'bus_info',
#  'que hora fretados': 'bus_info',
#  'quando sai fretado': 'bus_info',
#  'quando sai fretados': 'bus_info',
#  'quero saber lotação': 'bus_info',
#  ' fretados': 'bus_info',
#  'qual busao': 'bus_info',
#  'que hora fretado': 'bus_info',
#  'quando fretados': 'bus_info',
#  'quero saber fretado': 'bus_info',
#  'quando lotação': 'bus_info',
#  'quero que sai onibus': 'bus_info'}

# %%
keys, values = zip(*my_dict.items())
 
# printing keys and values separately
print ("keys : ", str(keys))
print ("values : ", str(values))
# Out:
# keys :  ('qual é professores na quinta', ' local na quarta', ' sala de manha', ' professores na terca', 'quero saber as local de manha', 'informe a aula na segunda', 'qual minha turma de tarde', 'minhas local de tarde', ' classes de manha', 'minhas grade que devo ir', ' horario de manha', 'diga a  classes na sexta', 'diz a grade ', 'informe a salas que devo ir', 'minhas disciplinas na segunda', ' classe na sexta', 'quero saber as sala na segunda', ' local ', ' disciplina de manha', 'minhas professores agora', 'diga a  sala na quinta', 'qual minha materia de manha', 'qual é professor ', 'quero minhas aulas de manha', ' disciplinas na quinta', 'quero saber as sala agora', ' aulas de noite', ' salas agora', ' classes agora', 'diz a disciplina na quarta', 'informe a local que devo ir', 'qual minha horario na sexta', 'quero saber as aula na quinta', 'quais as minhas classes ', 'quais as minhas horario de noite', 'qual é aula de tarde', 'minhas grade na sexta', 'quero saber as materia de noite', 'quais as minhas disciplina de manha', 'quais as minhas materia de manha', 'diz a salas na segunda', 'diz a local ', 'me fale as salas ', ' local de tarde', ' materia ', 'qual minha sala de manha', 'quero minhas materia na terca', 'quero saber as sala que devo ir', 'quero minhas materias na quinta', 'qual é grade ', 'quero minhas salas na quinta', 'quais as minhas aulas de manha', 'informe a sala ', 'diz a aula que devo ir', 'informe a classe na quinta', 'diz a materia de noite', 'diz a professores de noite', 'qual minha aulas de manha', 'diz a materia de tarde', 'me fale as materia na quinta', 'minhas aulas de tarde', 'quais as minhas local na terca', 'diz a turma na segunda', 'diga a  disciplina de noite', 'qual é horario ', 'me fale as aula ', 'informe a disciplina na quinta', 'quais as minhas sala na quarta', 'quero saber as grade na quinta', 'diga a  professores na quarta', 'quero minhas horario na terca', 'quero minhas turmas na quarta', 'minhas classe de manha', 'diz a turma de tarde', 'qual é materias que devo ir', 'quero saber as local na quarta', ' professores na segunda', 'quero minhas horario de manha', 'quais as minhas classes na quinta', 'me fale as disciplina de noite', 'qual é disciplina ', 'minhas disciplina na segunda', 'qual é sala ', 'qual é local na terca', 'quero saber as horario ', ' sala ', 'diga a  disciplinas ', 'me fale as horario de tarde', 'informe a turma na sexta', 'diz a aulas de noite', 'qual é local na quarta', ' turma de noite', 'diga a  aula de tarde', ' sala na segunda', ' professores na quinta', 'me fale as turmas que devo ir', 'diz a aula ', ' classe de tarde', 'qual é classes de tarde', 'quero minhas salas na terca', ' turma agora', 'qual minha disciplinas ', 'diga a  professor de manha', 'qual é turma na terca', ' classes que devo ir', 'diga a  turma ', ' materias ', ' aula agora', 'quero minhas materia de tarde', 'minhas sala na sexta', 'qual é disciplina agora', 'informe a disciplina de tarde', ' aulas que devo ir', ' classe que devo ir', 'informe a grade que devo ir', 'qual minha sala que devo ir', 'quero minhas disciplina agora', 'quais as minhas disciplinas ', 'me fale as disciplina na terca', 'minhas professores ', 'minhas classe na terca', ' disciplina na sexta', 'quero minhas professor na segunda', 'diz a turma na quarta', ' salas de noite', 'minhas aula ', 'quero minhas sala de manha', 'diz a professor na terca', ' professores ', 'diz a aulas na segunda', 'minhas turma ', 'minhas classe na segunda', 'informe a salas na terca', 'informe a grade de noite', 'informe a salas de noite', 'minhas disciplina na sexta', ' sala de tarde', 'diga a  professores de tarde', 'quero saber as professor na terca', 'quero minhas disciplinas na quinta', 'informe a classe na quarta', 'diz a turma agora', 'qual é turma de tarde', 'quero saber as disciplina na quinta', ' disciplina que devo ir', ' turmas na quarta', ' salas que devo ir', 'diz a disciplinas na sexta', 'me fale as sala de tarde', ' salas na sexta', ' ...
# values :  ('my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'my_classes', 'bus_info', 'bus_info', 'bus_info', 'bus_info', 'bus_info', 'bus_info', 'bus_info', 'bus_info', 'bus_info', 'bus_info', 'bus_info', 'bus_info', 'bus_info', 'bus_info', 'bus_info', 'bus_info', 'bus_info', 'bus_info', 'bus_info', 'bus_info', 'bus_info', 'bus_info', 'bus_info', 'bus_info', 'bus_info', 'bus_info')

# %% [markdown]
# # Frases para os fretados

# %%
# sinonimo de QUERO
list_bus1 = ('quero', 'desejo', 'pretendo', 'necessito', 'preciso', 'procuro')

# sinonimos de SABER
list_bus2 = ('saber', 'entender', 'me informar', 'conhecer')

# variacoes para QUE HORAS
list_bus3 = ('que horas', 'que momento', 'quando')

# sinonimos de PARTIR
list_bus4 = ('sai', 'parte')

# sinonimos de onibus
list_bus5 = ('o onibus', 'o busao', 'o fretado', 'o transporte', 'a lotação')

# %%
from random import choice

frases = []

for i in range(10000):
    a = choice(list_bus1)+' '+choice(list_bus2)+' '+choice(list_bus3)+' '+choice(list_bus4)+' '+choice(list_bus5)
    if a not in frases:
        frases.append(a)

print('quantidade de frases: ', len(frases))

# sorted(frases)[0:5]
frases[0:10]
# Out:
# quantidade de frases:  720
# ['necessito entender que horas parte o busao',
#  'quero entender que horas sai o onibus',
#  'quero conhecer que momento parte o fretado',
#  'pretendo conhecer que horas parte o fretado',
#  'preciso me informar quando sai o transporte',
#  'necessito me informar quando parte o transporte',
#  'necessito me informar quando parte o onibus',
#  'pretendo entender que momento parte o transporte',
#  'pretendo conhecer que horas parte o busao',
#  'procuro conhecer que momento sai a lotação']

# %% [markdown]
# # Frases para pedir as turmas

# %%
# sinonimo de QUERO
list1 = ('quero', 'desejo', 'pretendo', 'cogito', 'exijo', 'necessito', 'preciso', 'procuro', 'interesso-me')

# sinonimos de SABER
list2 = ('saber', 'entender', 'que me informe', 'conhecer', 'compreender')

# variacoes para QUE HORAS
list3 = ('minhas salas', 'minhas turmas', 'minha grade', 'minhas salas de aula', 'minhas classes', 'minha próxima aula', 'a próxima aula',
        'a turma seguinte', 'a seguinte sala')

# %%
frases = []

for i in range(1250):
    a = choice(list1)+' '+choice(list2)+' '+choice(list3)
    if a not in frases:
        frases.append(a)
print(len(frases))

# frases = sorted(frases)
frases[0:20]
# Out:
# 394
# ['exijo que me informe a turma seguinte',
#  'pretendo conhecer minhas salas de aula',
#  'preciso compreender minhas salas',
#  'interesso-me que me informe a turma seguinte',
#  'quero saber minhas classes',
#  'preciso que me informe minhas salas',
#  'necessito que me informe minhas salas de aula',
#  'necessito entender minhas salas',
#  'necessito conhecer a turma seguinte',
#  'preciso saber minhas classes',
#  'quero compreender a próxima aula',
#  'necessito compreender a próxima aula',
#  'pretendo saber minhas classes',
#  'cogito entender a seguinte sala',
#  'preciso saber minha grade',
#  'interesso-me entender minha grade',
#  'quero compreender a turma seguinte',
#  'preciso compreender a turma seguinte',
#  'procuro entender minhas salas de aula',
#  'necessito compreender minhas salas']
